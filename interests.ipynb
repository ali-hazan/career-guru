# %% [markdown]
# # Clustering Based on Holland Code

# %%
import pandas as pd

# %% [markdown]
# ## Loading data

# %%
df = pd.read_excel ('data\interests.xlsx')

# %%
df[:6]
# Out:
#   O*NET-SOC Code             Title Element ID   Element Name Scale ID  \
# 0     11-1011.00  Chief Executives    1.B.1.a      Realistic       OI
# 1     11-1011.00  Chief Executives    1.B.1.b  Investigative       OI
# 2     11-1011.00  Chief Executives    1.B.1.c       Artistic       OI
# 3     11-1011.00  Chief Executives    1.B.1.d         Social       OI
# 4     11-1011.00  Chief Executives    1.B.1.e   Enterprising       OI
# 5     11-1011.00  Chief Executives    1.B.1.f   Conventional       OI
#
#                Scale Name  Data Value     Date Domain Source
# 0  Occupational Interests        1.33  06/2008       Analyst
# 1  Occupational Interests        2.00  06/2008       Analyst
# 2  Occupational Interests        2.67  06/2008       Analyst
# 3  Occupational Interests        3.67  06/2008       Analyst
# 4  Occupational Interests        7.00  06/2008       Analyst
# 5  Occupational Interests        5.33  06/2008       Analyst

# %% [markdown]
# ## Data Cleaning
# Here we are only using RIASEC ( Realistic, Investigative, Artistic, Social, Enterprising, Conventional)

# %%
# Renaming the odd formated name
df.rename(columns = {'O*NET-SOC Code':'Code'}, inplace = True)

def rename_columns(columns)->dict:
    """
    Args  : Columns(list or panda dataframe columns)
    Return: Dictionary of columns, key as old name and value 
            as new formated name 
    """
    renamed_columns = {}
    
    for col in columns:
        renamed_columns[col]=col.replace(' ','_').lower()

    return renamed_columns
    

# Renaming column names
df.rename(columns = rename_columns(df.columns), inplace = True )

# %%
# Droping unwanted columns for our model
df = df.drop(['date','domain_source'],axis=1)

# %%
df
# Out:
#             code                              title element_id  \
# 0     11-1011.00                   Chief Executives    1.B.1.a
# 1     11-1011.00                   Chief Executives    1.B.1.b
# 2     11-1011.00                   Chief Executives    1.B.1.c
# 3     11-1011.00                   Chief Executives    1.B.1.d
# 4     11-1011.00                   Chief Executives    1.B.1.e
# ...          ...                                ...        ...
# 8761  53-7121.00  Tank Car, Truck, and Ship Loaders    1.B.1.e
# 8762  53-7121.00  Tank Car, Truck, and Ship Loaders    1.B.1.f
# 8763  53-7121.00  Tank Car, Truck, and Ship Loaders    1.B.1.g
# 8764  53-7121.00  Tank Car, Truck, and Ship Loaders    1.B.1.h
# 8765  53-7121.00  Tank Car, Truck, and Ship Loaders    1.B.1.i
#
#                     element_name scale_id                        scale_name  \
# 0                      Realistic       OI            Occupational Interests
# 1                  Investigative       OI            Occupational Interests
# 2                       Artistic       OI            Occupational Interests
# 3                         Social       OI            Occupational Interests
# 4                   Enterprising       OI            Occupational Interests
# ...                          ...      ...                               ...
# 8761                Enterprising       OI            Occupational Interests
# 8762                Conventional       OI            Occupational Interests
# 8763   First Interest High-Point       IH  Occupational Interest High-Point
# 8764  Second Interest High-Point       IH  Occupational Interest High-Point
# 8765   Third Interest High-Point       IH  Occupational Interest High-Point
#
#       data_value
# 0           1.33
# 1           2.00
# 2           2.67
# 3           3.67
# 4           7.00
# ...          ...
# 8761        2.00
# 8762        5.00
# 8763        1.00
# 8764        6.00
# 8765        0.00
#
# [8766 rows x 7 columns]

# %%
df=df[df['scale_id']=='OI']

# %%
df[:10]
# Out:
#           code                          title element_id   element_name  \
# 0   11-1011.00               Chief Executives    1.B.1.a      Realistic
# 1   11-1011.00               Chief Executives    1.B.1.b  Investigative
# 2   11-1011.00               Chief Executives    1.B.1.c       Artistic
# 3   11-1011.00               Chief Executives    1.B.1.d         Social
# 4   11-1011.00               Chief Executives    1.B.1.e   Enterprising
# 5   11-1011.00               Chief Executives    1.B.1.f   Conventional
# 9   11-1011.03  Chief Sustainability Officers    1.B.1.a      Realistic
# 10  11-1011.03  Chief Sustainability Officers    1.B.1.b  Investigative
# 11  11-1011.03  Chief Sustainability Officers    1.B.1.c       Artistic
# 12  11-1011.03  Chief Sustainability Officers    1.B.1.d         Social
#
#    scale_id              scale_name  data_value
# 0        OI  Occupational Interests        1.33
# 1        OI  Occupational Interests        2.00
# 2        OI  Occupational Interests        2.67
# 3        OI  Occupational Interests        3.67
# 4        OI  Occupational Interests        7.00
# 5        OI  Occupational Interests        5.33
# 9        OI  Occupational Interests        1.00
# 10       OI  Occupational Interests        4.33
# 11       OI  Occupational Interests        2.67
# 12       OI  Occupational Interests        2.33
