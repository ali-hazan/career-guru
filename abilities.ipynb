# %% [markdown]
# # Clustering Based on Holland Code

# %%
import pandas as pd

# %% [markdown]
# ## Loading data

# %%
df = pd.read_excel ('data\Abilities.xlsx')

# %%
df[:6]
# Out:
#   O*NET-SOC Code             Title Element ID           Element Name Scale ID  \
# 0     11-1011.00  Chief Executives  1.A.1.a.1     Oral Comprehension       IM
# 1     11-1011.00  Chief Executives  1.A.1.a.1     Oral Comprehension       LV
# 2     11-1011.00  Chief Executives  1.A.1.a.2  Written Comprehension       IM
# 3     11-1011.00  Chief Executives  1.A.1.a.2  Written Comprehension       LV
# 4     11-1011.00  Chief Executives  1.A.1.a.3        Oral Expression       IM
# 5     11-1011.00  Chief Executives  1.A.1.a.3        Oral Expression       LV
#
#    Scale Name  Data Value    N  Standard Error  Lower CI Bound  \
# 0  Importance        4.50  8.0            0.19            4.13
# 1       Level        4.88  8.0            0.13            4.63
# 2  Importance        4.25  8.0            0.16            3.93
# 3       Level        4.62  8.0            0.18            4.27
# 4  Importance        4.38  8.0            0.18            4.02
# 5       Level        5.00  8.0            0.00            5.00
#
#    Upper CI Bound Recommend Suppress Not Relevant     Date Domain Source
# 0            4.87                  N          NaN  07/2014       Analyst
# 1            5.12                  N            N  07/2014       Analyst
# 2            4.57                  N          NaN  07/2014       Analyst
# 3            4.98                  N            N  07/2014       Analyst
# 4            4.73                  N          NaN  07/2014       Analyst
# 5            5.00                  N            N  07/2014       Analyst

# %% [markdown]
# ## Data Cleaning
# Here we are only using RIASEC ( Realistic, Investigative, Artistic, Social, Enterprising, Conventional)

# %%
# Renaming the odd formated name
df.rename(columns = {'O*NET-SOC Code':'Code'}, inplace = True)

def rename_columns(columns)->dict:
    """
    Args  : Columns(list or panda dataframe columns)
    Return: Dictionary of columns, key as old name and value 
            as new formated name 
    """
    renamed_columns = {}
    
    for col in columns:
        renamed_columns[col]=col.replace(' ','_').lower()

    return renamed_columns
    

# Renaming column names
df.rename(columns = rename_columns(df.columns), inplace = True )

# %%
df.head()
# Out:
#          code             title element_id           element_name scale_id  \
# 0  11-1011.00  Chief Executives  1.A.1.a.1     Oral Comprehension       IM
# 1  11-1011.00  Chief Executives  1.A.1.a.1     Oral Comprehension       LV
# 2  11-1011.00  Chief Executives  1.A.1.a.2  Written Comprehension       IM
# 3  11-1011.00  Chief Executives  1.A.1.a.2  Written Comprehension       LV
# 4  11-1011.00  Chief Executives  1.A.1.a.3        Oral Expression       IM
#
#    scale_name  data_value    n  standard_error  lower_ci_bound  \
# 0  Importance        4.50  8.0            0.19            4.13
# 1       Level        4.88  8.0            0.13            4.63
# 2  Importance        4.25  8.0            0.16            3.93
# 3       Level        4.62  8.0            0.18            4.27
# 4  Importance        4.38  8.0            0.18            4.02
#
#    upper_ci_bound recommend_suppress not_relevant     date domain_source
# 0            4.87                  N          NaN  07/2014       Analyst
# 1            5.12                  N            N  07/2014       Analyst
# 2            4.57                  N          NaN  07/2014       Analyst
# 3            4.98                  N            N  07/2014       Analyst
# 4            4.73                  N          NaN  07/2014       Analyst

# %%
# Droping unwanted columns for our model
df = df.drop(['code','element_id','n','standard_error','lower_ci_bound','upper_ci_bound','recommend_suppress','not_relevant','date','domain_source','scale_name'],axis=1)

# %%
df.head()
# Out:
#               title           element_name scale_id  data_value
# 0  Chief Executives     Oral Comprehension       IM        4.50
# 1  Chief Executives     Oral Comprehension       LV        4.88
# 2  Chief Executives  Written Comprehension       IM        4.25
# 3  Chief Executives  Written Comprehension       LV        4.62
# 4  Chief Executives        Oral Expression       IM        4.38

# %%
df=df[df['scale_id']=='IM']

# %%
df = df.drop(['scale_id'],axis=1)

# %%
df=df.pivot(index='title',columns='element_name',values='data_value')

# %%
df=df.reset_index()

# %%
df.columns.name = None

# %%
df
# Out:
#                                                  title  Arm-Hand Steadiness  \
# 0                                          Accountants                 1.38
# 1                                               Actors                 2.00
# 2                                            Actuaries                 1.12
# 3                                       Acupuncturists                 3.25
# 4                                    Acute Care Nurses                 1.75
# ..                                                 ...                  ...
# 963                       Wind Energy Project Managers                 1.38
# 964                   Wind Turbine Service Technicians                 3.50
# 965  Woodworking Machine Setters, Operators, and Te...                 3.12
# 966                        Word Processors and Typists                 2.00
# 967                 Zoologists and Wildlife Biologists                 2.38
#
#      Auditory Attention  Category Flexibility  Control Precision  \
# 0                  1.88                  3.25               1.38
# 1                  2.00                  2.75               1.00
# 2                  2.00                  3.88               1.00
# 3                  1.88                  3.00               2.12
# 4                  2.12                  3.12               1.62
# ..                  ...                   ...                ...
# 963                2.38                  3.25               1.50
# 964                2.62                  3.12               3.12
# 965                3.12                  3.00               3.50
# 966                2.12                  3.00               2.00
# 967                2.12                  3.38               2.00
#
#      Deductive Reasoning  Depth Perception  Dynamic Flexibility  \
# 0                   3.88              1.75                 1.00
# 1                   2.88              1.00                 1.00
# 2                   4.12              1.62                 1.00
# 3                   3.88              2.00                 1.00
# 4                   4.00              2.00                 1.00
# ..                   ...               ...                  ...
# 963                 4.00              2.00                 1.00
# 964                 3.62              3.12                 1.62
# 965                 3.00              2.88                 1.62
# 966                 3.00              1.38                 1.00
# 967                 4.00              2.00                 1.00
#
#      Dynamic Strength  Explosive Strength  ...  Speed of Limb Movement  \
# 0                1.25                1.00  ...                    1.00
# 1                2.00                1.50  ...                    1.00
# 2                1.00                1.00  ...                    1.00
# 3                2.25                1.25  ...                    1.12
# 4                1.50                2.00  ...                    1.25
# ..                ...                 ...  ...                     ...
# 963              1.25                1.12  ...                    1.00
# 964              2.62                1.25  ...                    2.25
# 965              3.00                1.88  ...                    2.62
# 966              1.50                1.00  ...                    1.00
# 967              1.88                1.62  ...                    1.38
#
#      Stamina  Static Strength  Time Sharing  Trunk Strength  \
# 0       1.00             1.00          2.50            1.50
# 1       2.00             2.00          2.75            2.38
# 2       1.00             1.00          2.50            1.50
# 3       2.12             2.12          2.75            2.38
# 4       2.00             2.25          3.00            1.62
# ..       ...              ...           ...             ...
# 963     1.12             1.25          2.62            2.00
# 964     2.75             2.88          2.62            3.00
# 965     2.50             3.25          2.25            3.25
# 966     1.00             1.00          2.25            2.00
# 967     2.00             2.12          2.88            2.00
#
#      Visual Color Discrimination  Visualization  Wrist-Finger Speed  \
# 0                           2.00           2.25                1.38
# 1                           2.00           2.62                1.12
# 2                           2.00           2.50                1.25
# 3                           2.00           2.88                1.62
# 4                           3.00           2.62                1.38
# ..                           ...            ...                 ...
# 963                         2.25           2.88                2.00
# 964                         3.00           3.38                2.00
# 965                         2.62           3.12                2.62
# 966                         1.88           2.50                3.12
# 967                         2.75           2.88                2.00
#
#      Written Comprehension  Written Expression
# 0                     4.00                3.75
# 1                     3.88                2.88
# 2                     4.00                3.75
# 3                     3.62                3.12
# 4                     4.00                3.75
# ..                     ...                 ...
# 963                   4.00                3.88
# 964                   3.25                2.75
# 965                   2.88                2.00
# 966                   3.75                3.25
# 967                   4.12                4.00
#
# [968 rows x 53 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
interest_matrix = df[df.columns[1:]].values

# %%
similarity = cosine_similarity(interest_matrix, interest_matrix)

# %%
# creating a Series for the movie titles so they are associated to an ordered numerical
# list I will use in the function to match the indexes
indices = pd.Series(df.index)

#  defining the function that takes in movie title 
# as input and returns the top 10 recommended movies
def recommendations(title, cosine_sim = similarity):
    
    # initializing the empty list of recommended movies
    recommended_occupation = []
    
    # gettin the index of the movie that matches the title
    idx = indices[indices == title].index[0]
   

    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

    # getting the indexes of the 10 most similar movies
    top_10_indexes = list(score_series.iloc[1:11].index)
    
    # populating the list with the titles of the best 10 matching movies
    for i in top_10_indexes:
        recommended_occupation.append(list(df.index)[i])
        
    return recommended_occupation

# %%
 df.loc[recommendations(0)]
# Out:
#                           title  Arm-Hand Steadiness  Auditory Attention  \
# 202             Credit Analysts                 1.62                1.75
# 2                     Actuaries                 1.12                2.00
# 934  Treasurers and Controllers                 1.00                1.75
# 872      Statistical Assistants                 1.50                2.12
# 101             Budget Analysts                 1.00                1.88
# 60                     Auditors                 1.12                2.00
# 887          Survey Researchers                 1.38                1.75
# 322          Financial Analysts                 1.00                1.75
# 92             Biostatisticians                 1.88                1.88
# 518          Logistics Analysts                 1.50                2.00
#
#      Category Flexibility  Control Precision  Deductive Reasoning  \
# 202                  3.12               1.38                 3.75
# 2                    3.88               1.00                 4.12
# 934                  3.50               1.00                 4.00
# 872                  3.38               1.38                 3.62
# 101                  3.12               1.00                 3.88
# 60                   3.25               1.00                 4.00
# 887                  3.12               1.50                 4.00
# 322                  3.25               1.00                 4.00
# 92                   3.62               1.75                 4.12
# 518                  3.25               1.62                 3.75
#
#      Depth Perception  Dynamic Flexibility  Dynamic Strength  \
# 202              1.38                  1.0              1.00
# 2                1.62                  1.0              1.00
# 934              1.62                  1.0              1.25
# 872              1.25                  1.0              1.50
# 101              1.50                  1.0              1.00
# 60               1.62                  1.0              1.00
# 887              1.62                  1.0              1.00
# 322              1.62                  1.0              1.25
# 92               1.62                  1.0              1.25
# 518              1.88                  1.0              1.12
#
#      Explosive Strength  ...  Speed of Limb Movement  Stamina  \
# 202                 1.0  ...                    1.00     1.00
# 2                   1.0  ...                    1.00     1.00
# 934                 1.0  ...                    1.00     1.00
# 872                 1.0  ...                    1.00     1.00
# 101                 1.0  ...                    1.00     1.12
# 60                  1.0  ...                    1.00     1.00
# 887                 1.0  ...                    1.00     1.00
# 322                 1.0  ...                    1.00     1.00
# 92                  1.0  ...                    1.12     1.25
# 518                 1.0  ...                    1.00     1.00
#
#      Static Strength  Time Sharing  Trunk Strength  \
# 202             1.00          2.00            1.50
# 2               1.00          2.50            1.50
# 934             1.00          2.38            1.50
# 872             1.00          2.38            1.50
# 101             1.00          2.50            1.50
# 60              1.00          2.25            1.25
# 887             1.00          2.00            1.50
# 322             1.00          2.12            1.75
# 92              1.25          2.38            1.38
# 518             1.00          2.75            1.50
#
#      Visual Color Discrimination  Visualization  Wrist-Finger Speed  \
# 202                         1.75           1.88                1.25
# 2                           2.00           2.50                1.25
# 934                         1.88           2.38                1.25
# 872                         2.00           2.75                1.50
# 101                         2.12           2.12                1.12
# 60                          2.00           2.25                1.25
# 887                         1.75           2.12                1.25
# 322                         1.75           2.38                1.50
# 92                          1.75           3.00                1.38
# 518                         2.00           2.75                1.25
#
#      Written Comprehension  Written Expression
# 202                   3.88                3.38
# 2                     4.00                3.75
# 934                   4.12                4.00
# 872                   4.00                3.88
# 101                   4.00                3.88
# 60                    3.88                4.00
# 887                   4.12                4.12
# 322                   4.00                4.00
# 92                    4.12                3.88
# 518                   3.88                3.25
#
# [10 rows x 53 columns]

# %%
df
# Out:
#                                                  title  Arm-Hand Steadiness  \
# 0                                          Accountants                 1.38
# 1                                               Actors                 2.00
# 2                                            Actuaries                 1.12
# 3                                       Acupuncturists                 3.25
# 4                                    Acute Care Nurses                 1.75
# ..                                                 ...                  ...
# 963                       Wind Energy Project Managers                 1.38
# 964                   Wind Turbine Service Technicians                 3.50
# 965  Woodworking Machine Setters, Operators, and Te...                 3.12
# 966                        Word Processors and Typists                 2.00
# 967                 Zoologists and Wildlife Biologists                 2.38
#
#      Auditory Attention  Category Flexibility  Control Precision  \
# 0                  1.88                  3.25               1.38
# 1                  2.00                  2.75               1.00
# 2                  2.00                  3.88               1.00
# 3                  1.88                  3.00               2.12
# 4                  2.12                  3.12               1.62
# ..                  ...                   ...                ...
# 963                2.38                  3.25               1.50
# 964                2.62                  3.12               3.12
# 965                3.12                  3.00               3.50
# 966                2.12                  3.00               2.00
# 967                2.12                  3.38               2.00
#
#      Deductive Reasoning  Depth Perception  Dynamic Flexibility  \
# 0                   3.88              1.75                 1.00
# 1                   2.88              1.00                 1.00
# 2                   4.12              1.62                 1.00
# 3                   3.88              2.00                 1.00
# 4                   4.00              2.00                 1.00
# ..                   ...               ...                  ...
# 963                 4.00              2.00                 1.00
# 964                 3.62              3.12                 1.62
# 965                 3.00              2.88                 1.62
# 966                 3.00              1.38                 1.00
# 967                 4.00              2.00                 1.00
#
#      Dynamic Strength  Explosive Strength  ...  Speed of Limb Movement  \
# 0                1.25                1.00  ...                    1.00
# 1                2.00                1.50  ...                    1.00
# 2                1.00                1.00  ...                    1.00
# 3                2.25                1.25  ...                    1.12
# 4                1.50                2.00  ...                    1.25
# ..                ...                 ...  ...                     ...
# 963              1.25                1.12  ...                    1.00
# 964              2.62                1.25  ...                    2.25
# 965              3.00                1.88  ...                    2.62
# 966              1.50                1.00  ...                    1.00
# 967              1.88                1.62  ...                    1.38
#
#      Stamina  Static Strength  Time Sharing  Trunk Strength  \
# 0       1.00             1.00          2.50            1.50
# 1       2.00             2.00          2.75            2.38
# 2       1.00             1.00          2.50            1.50
# 3       2.12             2.12          2.75            2.38
# 4       2.00             2.25          3.00            1.62
# ..       ...              ...           ...             ...
# 963     1.12             1.25          2.62            2.00
# 964     2.75             2.88          2.62            3.00
# 965     2.50             3.25          2.25            3.25
# 966     1.00             1.00          2.25            2.00
# 967     2.00             2.12          2.88            2.00
#
#      Visual Color Discrimination  Visualization  Wrist-Finger Speed  \
# 0                           2.00           2.25                1.38
# 1                           2.00           2.62                1.12
# 2                           2.00           2.50                1.25
# 3                           2.00           2.88                1.62
# 4                           3.00           2.62                1.38
# ..                           ...            ...                 ...
# 963                         2.25           2.88                2.00
# 964                         3.00           3.38                2.00
# 965                         2.62           3.12                2.62
# 966                         1.88           2.50                3.12
# 967                         2.75           2.88                2.00
#
#      Written Comprehension  Written Expression
# 0                     4.00                3.75
# 1                     3.88                2.88
# 2                     4.00                3.75
# 3                     3.62                3.12
# 4                     4.00                3.75
# ..                     ...                 ...
# 963                   4.00                3.88
# 964                   3.25                2.75
# 965                   2.88                2.00
# 966                   3.75                3.25
# 967                   4.12                4.00
#
# [968 rows x 53 columns]
